# %% [markdown]
# # data analysis using pandas library

# %%
#opening the dataset to see the first 10 rows

import pandas as pd

dataFile=pd.read_csv('data_records.csv')

dataFile.head(100)
# Out:
#    Learner gender Teachers Gender  Teachers Age Community Outreach  \
# 0            Male            Male            44                 NO
# 1          Female          Female            43                YES
# 2          Female          Female            56                YES
# 3            Male            Male            52                 NO
# 4          Female          Female            59                YES
# ..            ...             ...           ...                ...
# 95         Female          Female            57                YES
# 96         Female          Female            59                YES
# 97         Female          Female            64                YES
# 98           Male          Female            28                 NO
# 99         Female          Female            27                 NO
#
#    Next of kin has a degree Know Career path has access to internet at home  \
# 0                        NO              YES                             NO
# 1                        NO              YES                             NO
# 2                       YES              YES                             NO
# 3                        NO              YES                             NO
# 4                        NO              YES                            YES
# ..                      ...              ...                            ...
# 95                      YES               NO                            YES
# 96                       NO              YES                             NO
# 97                      YES              YES                            YES
# 98                      YES               NO                            YES
# 99                       NO              YES                             NO
#
#    learning material preferred type of school Enrolled
# 0                Google search        Model A       NO
# 1                      YouTube        Model C      YES
# 2                Google search        Model A      YES
# 3                Google search        Model A      YES
# 4         Teachers explanation        Model A      YES
# ..                         ...            ...      ...
# 95               Google search        Model A      YES
# 96                       Books        Model B      YES
# 97                peer to peer        Model B      YES
# 98                       Books        Model B      YES
# 99        Teachers explanation        Model A       NO
#
# [100 rows x 10 columns]

# %%
#finding a small infomation about dataset

dataFile.describe()
# Out:
#        Teachers Age
# count   1000.000000
# mean      44.680000
# std       12.216171
# min       24.000000
# 25%       34.000000
# 50%       45.000000
# 75%       55.000000
# max       65.000000

# %%
#finding the average Age for teachers in Stem subjects  

dataFile["Teachers Age"].mean()
# Out:
# 44.68

# %%
# changin learner gender from categorical to numeric for analysis to be simple

dummy=pd.get_dummies(dataFile['Learner gender'])

# %%
dummy.head()
# Out:
#    Female  Male
# 0       0     1
# 1       1     0
# 2       1     0
# 3       0     1
# 4       1     0

# %%
#concatinate the numeric gender column into our dataset

dataFile2=pd.concat((dataFile,dummy),axis=1)

# %%
dataFile2.head()
# Out:
#   Learner gender Teachers Gender  Teachers Age Community Outreach  \
# 0           Male            Male            44                 NO
# 1         Female          Female            43                YES
# 2         Female          Female            56                YES
# 3           Male            Male            52                 NO
# 4         Female          Female            59                YES
#
#   Next of kin has a degree Know Career path has access to internet at home  \
# 0                       NO              YES                             NO
# 1                       NO              YES                             NO
# 2                      YES              YES                             NO
# 3                       NO              YES                             NO
# 4                       NO              YES                            YES
#
#   learning material preferred type of school Enrolled  Female  Male
# 0               Google search        Model A       NO       0     1
# 1                     YouTube        Model C      YES       1     0
# 2               Google search        Model A      YES       1     0
# 3               Google search        Model A      YES       0     1
# 4        Teachers explanation        Model A      YES       1     0

# %%
# droping a learner gender categorical column from dataset

dataFile2=dataFile2.drop(['Learner gender'],axis=1)

# %%
dataFile2.head()
# Out:
#   Teachers Gender  Teachers Age Community Outreach Next of kin has a degree  \
# 0            Male            44                 NO                       NO
# 1          Female            43                YES                       NO
# 2          Female            56                YES                      YES
# 3            Male            52                 NO                       NO
# 4          Female            59                YES                       NO
#
#   Know Career path has access to internet at home learning material preferred  \
# 0              YES                             NO               Google search
# 1              YES                             NO                     YouTube
# 2              YES                             NO               Google search
# 3              YES                             NO               Google search
# 4              YES                            YES        Teachers explanation
#
#   type of school Enrolled  Female  Male
# 0        Model A       NO       0     1
# 1        Model C      YES       1     0
# 2        Model A      YES       1     0
# 3        Model A      YES       0     1
# 4        Model A      YES       1     0

# %%
#droping female from dataset since it is also represented in male column as 0 and male as 1

dataFile2=dataFile2.drop(['Female'],axis=1)

# %%
dataFile2.head()
# Out:
#   Teachers Gender  Teachers Age Community Outreach Next of kin has a degree  \
# 0            Male            44                 NO                       NO
# 1          Female            43                YES                       NO
# 2          Female            56                YES                      YES
# 3            Male            52                 NO                       NO
# 4          Female            59                YES                       NO
#
#   Know Career path has access to internet at home learning material preferred  \
# 0              YES                             NO               Google search
# 1              YES                             NO                     YouTube
# 2              YES                             NO               Google search
# 3              YES                             NO               Google search
# 4              YES                            YES        Teachers explanation
#
#   type of school Enrolled  Male
# 0        Model A       NO     1
# 1        Model C      YES     0
# 2        Model A      YES     0
# 3        Model A      YES     1
# 4        Model A      YES     0

# %%
#renaming male column back to learner gender since male=1 and female=0, ....to avoid confution 

dataFile2=dataFile2.rename(columns={"Male":"learner gender"})

# %%
dataFile2.head()
# Out:
#   Teachers Gender  Teachers Age Community Outreach Next of kin has a degree  \
# 0            Male            44                 NO                       NO
# 1          Female            43                YES                       NO
# 2          Female            56                YES                      YES
# 3            Male            52                 NO                       NO
# 4          Female            59                YES                       NO
#
#   Know Career path has access to internet at home learning material preferred  \
# 0              YES                             NO               Google search
# 1              YES                             NO                     YouTube
# 2              YES                             NO               Google search
# 3              YES                             NO               Google search
# 4              YES                            YES        Teachers explanation
#
#   type of school Enrolled  learner gender
# 0        Model A       NO               1
# 1        Model C      YES               0
# 2        Model A      YES               0
# 3        Model A      YES               1
# 4        Model A      YES               0

# %%
dummy2=pd.get_dummies(dataFile2['Community Outreach'])

# %%
dummy2.head()
# Out:
#    NO  YES
# 0   1    0
# 1   0    1
# 2   0    1
# 3   1    0
# 4   0    1

# %%
dataFile3=pd.concat((dataFile2,dummy2),axis=1)

# %%
dataFile3.head()
# Out:
#   Teachers Gender  Teachers Age Community Outreach Next of kin has a degree  \
# 0            Male            44                 NO                       NO
# 1          Female            43                YES                       NO
# 2          Female            56                YES                      YES
# 3            Male            52                 NO                       NO
# 4          Female            59                YES                       NO
#
#   Know Career path has access to internet at home learning material preferred  \
# 0              YES                             NO               Google search
# 1              YES                             NO                     YouTube
# 2              YES                             NO               Google search
# 3              YES                             NO               Google search
# 4              YES                            YES        Teachers explanation
#
#   type of school Enrolled  learner gender  NO  YES
# 0        Model A       NO               1   1    0
# 1        Model C      YES               0   0    1
# 2        Model A      YES               0   0    1
# 3        Model A      YES               1   1    0
# 4        Model A      YES               0   0    1

# %%
dataFile3=dataFile3.drop(['Community Outreach'],axis=1)

# %%
dataFile3.head()
# Out:
#   Teachers Gender  Teachers Age Next of kin has a degree Know Career path  \
# 0            Male            44                       NO              YES
# 1          Female            43                       NO              YES
# 2          Female            56                      YES              YES
# 3            Male            52                       NO              YES
# 4          Female            59                       NO              YES
#
#   has access to internet at home learning material preferred type of school  \
# 0                             NO               Google search        Model A
# 1                             NO                     YouTube        Model C
# 2                             NO               Google search        Model A
# 3                             NO               Google search        Model A
# 4                            YES        Teachers explanation        Model A
#
#   Enrolled  learner gender  NO  YES
# 0       NO               1   1    0
# 1      YES               0   0    1
# 2      YES               0   0    1
# 3      YES               1   1    0
# 4      YES               0   0    1

# %%
dataFile3=dataFile3.drop(['NO'],axis=1)

# %%
dataFile3.head()
# Out:
#   Teachers Gender  Teachers Age Next of kin has a degree Know Career path  \
# 0            Male            44                       NO              YES
# 1          Female            43                       NO              YES
# 2          Female            56                      YES              YES
# 3            Male            52                       NO              YES
# 4          Female            59                       NO              YES
#
#   has access to internet at home learning material preferred type of school  \
# 0                             NO               Google search        Model A
# 1                             NO                     YouTube        Model C
# 2                             NO               Google search        Model A
# 3                             NO               Google search        Model A
# 4                            YES        Teachers explanation        Model A
#
#   Enrolled  learner gender  YES
# 0       NO               1    0
# 1      YES               0    1
# 2      YES               0    1
# 3      YES               1    0
# 4      YES               0    1

# %%
dataFile3=dataFile3.rename(columns={"YES":"Community Outreach"})

# %%
dataFile3.head()
# Out:
#   Teachers Gender  Teachers Age Next of kin has a degree Know Career path  \
# 0            Male            44                       NO              YES
# 1          Female            43                       NO              YES
# 2          Female            56                      YES              YES
# 3            Male            52                       NO              YES
# 4          Female            59                       NO              YES
#
#   has access to internet at home learning material preferred type of school  \
# 0                             NO               Google search        Model A
# 1                             NO                     YouTube        Model C
# 2                             NO               Google search        Model A
# 3                             NO               Google search        Model A
# 4                            YES        Teachers explanation        Model A
#
#   Enrolled  learner gender  Community Outreach
# 0       NO               1                   0
# 1      YES               0                   1
# 2      YES               0                   1
# 3      YES               1                   0
# 4      YES               0                   1

# %%
dummy3 = pd.get_dummies(dataFile3['Know Career path'])

# %%
dummy3.head()
# Out:
#    NO  YES
# 0   0    1
# 1   0    1
# 2   0    1
# 3   0    1
# 4   0    1

# %%
dataFile3 = pd.concat((dataFile3,dummy3), axis=1)

# %%
dataFile3.head()
# Out:
#   Teachers Gender  Teachers Age Next of kin has a degree Know Career path  \
# 0            Male            44                       NO              YES
# 1          Female            43                       NO              YES
# 2          Female            56                      YES              YES
# 3            Male            52                       NO              YES
# 4          Female            59                       NO              YES
#
#   has access to internet at home learning material preferred type of school  \
# 0                             NO               Google search        Model A
# 1                             NO                     YouTube        Model C
# 2                             NO               Google search        Model A
# 3                             NO               Google search        Model A
# 4                            YES        Teachers explanation        Model A
#
#   Enrolled  learner gender  Community Outreach  NO  YES
# 0       NO               1                   0   0    1
# 1      YES               0                   1   0    1
# 2      YES               0                   1   0    1
# 3      YES               1                   0   0    1
# 4      YES               0                   1   0    1

# %%
dataFile3 = dataFile3.drop(['Know Career path'],axis=1)

# %%
dataFile3.head()
# Out:
#   Teachers Gender  Teachers Age Next of kin has a degree  \
# 0            Male            44                       NO
# 1          Female            43                       NO
# 2          Female            56                      YES
# 3            Male            52                       NO
# 4          Female            59                       NO
#
#   has access to internet at home learning material preferred type of school  \
# 0                             NO               Google search        Model A
# 1                             NO                     YouTube        Model C
# 2                             NO               Google search        Model A
# 3                             NO               Google search        Model A
# 4                            YES        Teachers explanation        Model A
#
#   Enrolled  learner gender  Community Outreach  NO  YES
# 0       NO               1                   0   0    1
# 1      YES               0                   1   0    1
# 2      YES               0                   1   0    1
# 3      YES               1                   0   0    1
# 4      YES               0                   1   0    1

# %%
dataFile3 = dataFile3.drop(['NO'],axis=1)

# %%
dataFile3.head()
# Out:
#   Teachers Gender  Teachers Age Next of kin has a degree  \
# 0            Male            44                       NO
# 1          Female            43                       NO
# 2          Female            56                      YES
# 3            Male            52                       NO
# 4          Female            59                       NO
#
#   has access to internet at home learning material preferred type of school  \
# 0                             NO               Google search        Model A
# 1                             NO                     YouTube        Model C
# 2                             NO               Google search        Model A
# 3                             NO               Google search        Model A
# 4                            YES        Teachers explanation        Model A
#
#   Enrolled  learner gender  Community Outreach  YES
# 0       NO               1                   0    1
# 1      YES               0                   1    1
# 2      YES               0                   1    1
# 3      YES               1                   0    1
# 4      YES               0                   1    1

# %%
dataFile3 = dataFile3.rename(columns={"YES":"Know Career path"})

# %%
dataFile3.head()
# Out:
#   Teachers Gender  Teachers Age Next of kin has a degree  \
# 0            Male            44                       NO
# 1          Female            43                       NO
# 2          Female            56                      YES
# 3            Male            52                       NO
# 4          Female            59                       NO
#
#   has access to internet at home learning material preferred type of school  \
# 0                             NO               Google search        Model A
# 1                             NO                     YouTube        Model C
# 2                             NO               Google search        Model A
# 3                             NO               Google search        Model A
# 4                            YES        Teachers explanation        Model A
#
#   Enrolled  learner gender  Community Outreach  Know Career path
# 0       NO               1                   0                 1
# 1      YES               0                   1                 1
# 2      YES               0                   1                 1
# 3      YES               1                   0                 1
# 4      YES               0                   1                 1
